# %%
import pandas as pd
import numpy as np
from scipy.io import wavfile
import matplotlib.pyplot as plt
import csv
import glob  
import tensorflow as tf

# %%
T_sync=[]
Ini_csv=[]
path1 = '*.csv'
files=glob.glob(path1)
for f in files:
    if '_TimeSync.csv' in f:
        T_sync.append(f)
    elif '_TimeSync_1.csv' in f:
        T_sync.append(f)
    else:
        Ini_csv.append(f)

T_sync.sort();
Ini_csv.sort();
print(T_sync)
print(Ini_csv)

start_time=[]
stop_time=[]
for t in Ini_csv:
    with open(t, newline='') as f:
        reader = csv.reader(f)
        for row in reader:       
            print(row)
        start_time.append(row[4])
        stop_time.append(row[5])
        f.close()
print(start_time)
print(stop_time)

Total_Gestures=[]
Total_DeltaTime=[]
for count,t in enumerate (T_sync):
    with open(t, newline='') as f:
        reader = csv.reader(f)
        Gestures=[]
        DeltaTimes=[]
        i=0
        for row in reader: 
            if i==1:
                Gesture=row[0]
                CurrentTime=row[1]
                DeltaTime=int(CurrentTime)-int(start_time[count])
                Gestures.append(Gesture)
                DeltaTimes.append(DeltaTime)
            i=1
        Total_Gestures.append(Gestures)
        Total_DeltaTime.append(DeltaTimes)
        f.close()
print(len(Total_Gestures))
# Out:
# ['st145634_TimeSync.csv', 'st152833_TimeSync.csv', 'st152839_TimeSync.csv', 'st152840_TimeSync.csv', 'st152867_TimeSync.csv', 'st152881_TimeSync.csv', 'st152939_TimeSync.csv', 'st152961_TimeSync.csv', 'st153005_TimeSync.csv', 'st153063_TimeSync.csv', 'st153573_TimeSync.csv', 'st158058_TimeSync.csv', 'st158208_TimeSync.csv', 'st158409_TimeSync.csv', 'st158522_TimeSync.csv', 'st158671_TimeSync.csv', 'st158767_TimeSync.csv', 'st158777_TimeSync.csv', 'st158788_TimeSync.csv', 'st158823_TimeSync.csv', 'st158830_TimeSync.csv', 'st158956_TimeSync.csv', 'st158982_TimeSync.csv', 'st158991_TimeSync.csv', 'st159017_TimeSync.csv', 'st159017_TimeSync_1.csv', 'st159103_TimeSync.csv', 'st159123_TimeSync.csv', 'st159217_TimeSync.csv', 'st159237_TimeSync.csv', 'st159254_TimeSync.csv', 'st159343_TimeSync.csv', 'st159603_TimeSync.csv', 'st159630_TimeSync.csv', 'st362203_TimeSync.csv']
# ['st145634.csv', 'st152833.csv', 'st152839.csv', 'st152840.csv', 'st152867.csv', 'st152881.csv', 'st152939.csv', 'st152961.csv', 'st153005.csv', 'st153063.csv', 'st153573.csv', 'st158058.csv', 'st158208.csv', 'st158409.csv', 'st158522.csv', 'st158671.csv', 'st158767.csv', 'st158777.csv', 'st158788.csv', 'st158823.csv', 'st158830.csv', 'st158956.csv', 'st158982.csv', 'st158991.csv', 'st159017.csv', 'st159017_1.csv', 'st159103.csv', 'st159123.csv', 'st159217.csv', 'st159237.csv', 'st159254.csv', 'st159343.csv', 'st159603.csv', 'st159630.csv', 'st362203.csv']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st145634', '26', 'student', 'Male', '1529522325483', '1529523136754']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st152833', '27', 'student', 'Male', '1529233686903', '1529235469819']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st152839', '24', 'student', 'Male', '1529265523379', '1529266950681']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st152840', '24', 'Student', 'Male', '1531163592809', '1531164677059']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st152867', '26', 'Student', 'Male', '1531159795618', '1531160893340']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st152881', '27', 'student', 'Male', '1531143975862', '1531145343132']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st152939', '27', 'student', 'Male', '1529345825594', '1529346706644']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st152961', '25', 'Student', 'Male', '1529237885231', '1529239690144']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st153005', '24', 'Student', 'Female', '1531157192879', '1531158217341']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st153063', '27', 'Student', 'Male', '1529440324653', '1529441164033']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st153573', '26', 'student', 'Male', '1529268401186', '1529269776476']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st158058', '26', 'student', 'Male', '1529941746057', '1529942391839']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st158208', '23', 'Student', 'Male', '1531150242063', '1531151247570']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st158409', '25', 'Student', 'Male', '1529865345226', '1529866126366']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st158522', '26', 'student', 'Male', '1529349377316', '1529350166409']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st158671', '22', 'student', 'Female', '1531178209939', '1531179464542']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st158767', '25', 'Student', 'Male', '1531514073661', '1531515219758']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st158777', '25', 'student', 'Male', '1531506944291', '1531507708426']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st158788', '23', 'student', 'Male', '1531501295123', '1531502075164']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st158823', '25', 'Student', 'Male', '1529347358297', '1529348098141']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st158830', '27', 'student', 'Male', '1531168485004', '1531169589702']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st158956', '25', 'student', 'Male', '1531079548845', '1531080824342']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st158982', '25', 'student ', 'Female', '1529863667636', '1529864782897']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st158991', '23', 'student', 'Female', '1531169849099', '1531170894244']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st159017', '28', 'Student', 'Male', '1529947317628', '1529947916836']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st159017_1', '28', 'Student', 'Male', '1529947995321', '1529948553319']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st159103', '25', 'student', 'Male', '1531512417281', '1531513385439']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st159123', '23', 'student', 'Male', '1531506001816', '1531506787303']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st159217', '26', 'student', 'Male', '1529356324312', '1529357056720']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st159237', '26', 'Student', 'Female', '1529872262229', '1529872921688']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st159254', '25', 'student', 'Male', '1531077200190', '1531078564809']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st159343', '24', 'student', 'Female', '1529944427768', '1529945117437']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st159603', '26', 'Student', 'Male', '1529524643881', '1529525793453']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st159630', '23', 'student', 'Male', '1529943108306', '1529944083911']
# ['Name', 'Age', 'Profession', 'Gender', 'Start_Time', 'End_Time']
# ['st362203', '24', 'student', 'Male', '1529945314711', '1529945945043']
# ['1529522325483', '1529233686903', '1529265523379', '1531163592809', '1531159795618', '1531143975862', '1529345825594', '1529237885231', '1531157192879', '1529440324653', '1529268401186', '1529941746057', '1531150242063', '1529865345226', '1529349377316', '1531178209939', '1531514073661', '1531506944291', '1531501295123', '1529347358297', '1531168485004', '1531079548845', '1529863667636', '1531169849099', '1529947317628', '1529947995321', '1531512417281', '1531506001816', '1529356324312', '1529872262229', '1531077200190', '1529944427768', '1529524643881', '1529943108306', '1529945314711']
# ['1529523136754', '1529235469819', '1529266950681', '1531164677059', '1531160893340', '1531145343132', '1529346706644', '1529239690144', '1531158217341', '1529441164033', '1529269776476', '1529942391839', '1531151247570', '1529866126366', '1529350166409', '1531179464542', '1531515219758', '1531507708426', '1531502075164', '1529348098141', '1531169589702', '1531080824342', '1529864782897', '1531170894244', '1529947916836', '1529948553319', '1531513385439', '1531506787303', '1529357056720', '1529872921688', '1531078564809', '1529945117437', '1529525793453', '1529944083911', '1529945945043']
# 35

# %%
Total_Ges1=[]
i=0
for Gest1 in Total_Gestures:    
    Ges1=[]
    Ges2=[]
    flg=0
    flg1=1
    for k in Gest1:
        if flg==1:
            a,b=k.split('_',1)
            if flg1==1:
                Ges1.append(a)
                flg1=0
            else:
                flg1=1
            Ges2.append(b)
        flg=1
        
    Total_Ges1.append(Ges1)
    i=i+1
print(Total_Ges1)

Total_Start_ti=[]
Total_Stop_ti=[]
for DeltaTimes in Total_DeltaTime:
    Start_ti=[]
    Stop_ti=[]
    flg=1
    for k in DeltaTimes:
        if flg==1:
            Start_ti.append(k)
            flg=0
        elif flg==0:
            Stop_ti.append(k)
            flg=1
    Total_Start_ti.append(Start_ti)
    Total_Stop_ti.append(Stop_ti)
print(Total_Start_ti)
print(Total_Stop_ti)

Total_Label_TS=[]
Label_TS_temp=[]

flg=0
i=0

for Gest_sample,t_start,t_stop in zip(Total_Ges1,Total_Start_ti,Total_Stop_ti):
    Label_TS=[]
    for k,t1,t2 in zip(Gest_sample,t_start,t_stop):
        if flg==0:
            Label_TS_temp=[k,t1,t2]
            Label_TS.append(Label_TS_temp)
    Total_Label_TS.append(Label_TS)
len(Total_Label_TS)
# Out:
# [['Circle', 'Circle', 'Noise', 'Equal', 'Plus', 'Plus', 'Tap', 'V', 'V', 'Divide', 'Double', 'Plus', 'Eleven', 'Divide', 'One', 'Eleven', 'V', 'One', 'Eleven', 'Noise', 'Double', 'Divide', 'Divide', 'Plus', 'Divide', 'Divide', 'Double', 'Divide', 'Eleven', 'Tap', 'Eleven', 'Noise', 'Plus', 'Tap', 'Minus', 'Tap', 'Minus', 'One', 'V', 'Circle', 'Equal', 'Plus', 'V', 'Plus', 'Plus', 'V', 'V', 'Circle', 'Tap', 'Plus', 'Tap', 'Divide', 'Equal', 'Tap', 'Divide', 'Noise', 'Divide', 'Tap', 'One', 'Eleven', 'Divide', 'Noise', 'Divide', 'Noise', 'Eleven', 'Noise', 'Noise', 'V', 'One', 'Divide', 'Plus', 'V', 'Divide', 'Divide', 'Tap', 'V', 'Divide', 'V', 'Tap', 'Minus', 'V', 'Plus', 'Noise', 'Tap', 'Minus', 'Divide', 'Circle', 'Tap', 'One', 'Tap', 'Plus', 'Equal', 'Eleven', 'Circle', 'Noise', 'Divide', 'Plus', 'Divide', 'Equal', 'Double', 'One', 'Equal', 'Noise', 'V', 'Tap', 'Tap', 'Noise', 'V', 'One', 'Noise', 'Double', 'Tap', 'One', 'Eleven', 'Plus', 'One', 'Circle', 'Eleven', 'Noise', 'V', 'Equal', 'Divide', 'Plus', 'Plus', 'Equal', 'Equal', 'Tap', 'V', 'Tap', 'Tap', 'Equal', 'Tap', 'Circle', 'V', 'Double', 'Circle', 'One', 'Noise', 'Minus', 'Divide', 'V', 'Divide', 'Circle', 'Noise', 'Divide', 'Divide', 'Plus', 'Circle', 'Plus', 'Circle', 'One', 'Plus', 'Tap', 'One', 'One', 'V', 'Minus', 'Tap', 'Plus', 'Minus', 'Noise', 'Tap', 'Equal', 'Divide', 'Plus', 'Divide', 'V', 'One', 'One', 'Tap', 'Eleven', 'Noise', 'Equal', 'One', 'Tap', 'Divide', 'Double', 'Double', 'Equal', 'Circle', 'Equal', 'Equal', 'Equal', 'Tap', 'V', 'Noise', 'Plus', 'Equal', 'Eleven', 'Noise', 'Circle', 'Eleven', 'Tap', 'Double', 'One', 'Equal', 'One', 'Eleven', 'Double', 'V'], ['Circle', 'Eleven', 'Noise', 'Circle', 'Minus', 'Plus', 'Equal', 'Minus', 'Noise', 'V', 'Double', 'One', 'Divide', 'Circle', 'Divide', 'Equal', 'Divide', 'Tap', 'Divide', 'Equal', 'Eleven', 'Circle', 'Equal', 'Circle', 'Double', 'Circle', 'Plus', 'Divide', 'One', 'Equal', 'Equal', 'Equal', 'Minus', 'Noise', 'V', 'Equal', 'Noise', 'Plus', 'One', 'Equal', 'Noise', 'Eleven', 'Plus', 'Plus', 'Noise', 'One', 'Divide', 'Minus', 'Divide', 'Minus', 'Equal', 'Divide', 'Circle', 'Minus', 'Divide', 'Circle', 'V', 'Noise', 'Eleven', 'Divide', 'V', 'Noise', 'Double', 'One', 'Tap', 'Double', 'Circle', 'Double', 'Divide', 'One', 'Minus', 'Minus', 'Equal', 'Tap', 'V', 'Circle', 'Noise', 'Divide', 'Tap', 'V', 'Tap', 'Equal', 'Tap', 'Minus', 'Divide', 'One', 'Minus', 'V', 'Minus', 'Circle', 'Minus', 'Plus', 'Equal', 'Minus', 'Plus', 'Noise', 'Divide', 'Circle', 'One', 'V', 'Double', 'Eleven', 'Eleven', 'Circle', 'One', 'One', 'Divide', 'Equal', 'V', 'V', 'Tap', 'Eleven', 'Equal', 'Noise', 'Minus', 'Divide', 'Equal', 'Tap', 'Noise', 'V', 'Noise', 'V', 'V', 'Eleven', 'Noise', 'Minus', 'Double', 'Minus', 'Equal', 'Divide', 'Minus', 'One', 'Equal', 'Tap', 'Circle', 'Circle', 'Equal', 'Noise', 'V', 'Plus', 'Eleven', 'V', 'Eleven', 'Plus', 'Minus', 'Circle', 'One', 'Divide', 'Minus', 'Circle', 'Noise', 'Plus', 'Eleven', 'Eleven', 'Equal', 'Minus', 'Noise', 'Circle', 'Double', 'Double', 'Minus', 'Eleven', 'One', 'Plus', 'One', 'Circle', 'Plus', 'Eleven', 'One', 'Tap', 'V', 'Minus', 'Divide', 'Tap', 'Circle', 'Circle', 'Double', 'Divide', 'Minus', 'Equal', 'Eleven', 'V', 'Eleven', 'Plus', 'Double', 'Noise', 'Tap', 'One', 'Tap', 'Plus', 'Double', 'Plus', 'V', 'Double', 'Noise', 'Tap', 'Minus', 'V', 'Circle', 'Noise', 'One', 'Double', 'Plus', 'Double', 'Double', 'Circle', 'Plus', 'Minus', 'Double', 'Circle', 'Tap', 'Minus', 'Circle', 'Divide', 'Eleven', 'Plus', 'Tap', 'Double', 'Double', 'Divide', 'Divide', 'Minus', 'Circle', 'V', 'Circle', 'Divide', 'V', 'Eleven', 'Circle', 'One', 'Tap', 'Noise', 'One', 'Plus', 'Tap', 'Circle', 'Noise', 'Noise', 'Circle', 'Divide', 'Divide', 'V', 'V', 'Noise', 'V', 'V', 'Tap', 'One', 'Minus', 'V', 'Circle', 'Double', 'Eleven', 'Equal', 'V', 'Plus', 'Plus', 'Circle', 'Plus', 'Tap', 'Plus', 'Noise', 'Tap', 'One', 'Circle', 'Circle', 'V', 'Divide', 'Tap', 'Tap', 'Eleven', 'Double', 'Equal ...
, 355793, 359310, 361947, 365781, 369355, 372959, 376702, 380044, 382835, 385304, 388437, 392937, 395821, 399982, 403446, 407556, 411187, 414251, 417257, 419741, 423257, 426847, 431145, 435397, 440024, 443407, 445906, 449701, 453444, 459204, 462739, 465427, 468457, 472616, 475084, 477369, 479807, 483065, 486926, 489426, 492562, 496987, 500962, 503758, 507144, 510101, 514263, 517843, 522585, 526710, 529813, 532973, 535722, 539160, 541830, 544004, 547411, 550257, 552817, 558032, 561772, 564605, 567472, 570269, 573542, 576418, 581114, 583396, 585629, 587809, 592183, 594577, 597432, 599633, 602039, 604737, 607363, 609485, 611527, 613853, 616059, 619095, 621198, 624612, 626972, 629968, 633184, 635591, 637947, 641432, 644164, 646998, 649732, 651989, 656965, 659956, 661922, 664124, 667935, 671635, 674600, 677175, 680698, 686021, 687944, 690435, 693371, 697088, 700985, 704176, 706649, 710174, 712680, 715003, 717616, 720423, 722532, 725234, 727695, 729595, 731661, 734082, 737082, 739624, 742663, 744555, 746854, 751127, 754363, 757544, 759871, 762383, 764826, 767467, 770701, 773047, 776165, 778669, 780915, 783106, 786823, 789855, 792617, 794509, 796950, 800444, 806246, 809049, 812239, 815536, 817893, 821557, 824923, 827822, 830954, 833353, 835770, 838087, 841422, 845480, 849698, 852919, 920717, 923339, 926416, 929496, 932619, 936149, 938334, 941341, 945523, 948328, 950678, 953361, 956468, 958825, 962650, 964719, 966749, 969516, 972054, 975211, 979882, 982360, 985639, 988894, 992046, 995005, 996906, 999913, 1002697, 1006795, 1008954, 1012795, 1015727, 1019171, 1022146, 1024528, 1029805, 1032324, 1036445, 1039587, 1041701, 1043885, 1045973, 1048886, 1051312, 1054205, 1057006, 1060061, 10630 ...
# 35

# %%
Total_data=[]
path2 = '*.wav'
files=glob.glob(path2)
files.sort();
for f in files:
    fs,data=wavfile.read(f);
    Total_data.append(data)
    #print(f)
Total_data

Total_data1=[]
Total_data2=[]
for t_data in Total_data:
    Total_data1.append(t_data[:,0])
    Total_data2.append(t_data[:,1])

# %%
len(Total_Label_TS)
# Out:
# 35

# %%
    
"""
Circle  ---1
Plus    ---2
V       ---3
Double  ---4
One     ---5
Divide  ---6
Noise   ---7


"""
label={'Circle':1,'Plus':2,'V':3,'Double':4,'One':5,'Divide':6,'Noise':7}
invlabel=dict([[v,k] for k,v in label.items()])
Data_withLabel=[]
Data_withLabel1=[]
temp=[]
temp1=[]

data_temp=[]
data_temp1=[]
label_check=[]

X_data_temp=[]
X_data_temp1=[]
X_data_circle=[]
X_data_circle1=[]
X_data_plus=[]
X_data_plus1=[]
X_data_double=[]
X_data_double1=[]
X_data_one=[]
X_data_one1=[]
X_data_divide=[]
X_data_divide1=[]
X_data_v=[]
X_data_v1=[]
X_data_noise=[]
X_data_noise1=[]
i=0
j=0
Case_Sw=None

for t_data1,t_data2,t_Label_TS in zip(Total_data1,Total_data2,Total_Label_TS):
     for j in range(0,len(t_Label_TS),1):
        start=float(t_Label_TS[j][1])*44.1
        stop= float(t_Label_TS[j][2])*44.1
        Case_Sw=t_Label_TS[j][0]
        X_data_temp=t_data1[int(start+10000):int(stop-10000)]
        X_data_temp1=t_data2[int(start+10000):int(stop-10000)]
        for t in range (0, len(X_data_temp),16):
                data_temp.append(X_data_temp[t])
                data_temp1.append(X_data_temp1[t])
        X_data_temp=data_temp
        X_data_temp1=data_temp1
        data_temp=[]
        data_temp1=[]
        if Case_Sw == "Circle":
            X_data_circle.append(X_data_temp)
            X_data_circle1.append(X_data_temp1)
            temp=[X_data_temp,label[Case_Sw]]
            Data_withLabel.append(temp)
            label_check.append(Case_Sw)
            temp1=[X_data_temp1,label[Case_Sw]]
            Data_withLabel1.append(temp1)
            temp=[]
            temp1=[]
        elif Case_Sw=="Plus":
            X_data_plus.append(X_data_temp)
            X_data_plus1.append(X_data_temp1)
            temp=[X_data_temp,label[Case_Sw]]
            Data_withLabel.append(temp)
            label_check.append(Case_Sw)
            temp1=[X_data_temp1,label[Case_Sw]]
            Data_withLabel1.append(temp1)
            temp=[]
            temp1=[]
        elif Case_Sw=="V":
            X_data_v.append(X_data_temp)
            X_data_v1.append(X_data_temp1)
            temp=[X_data_temp,label[Case_Sw]]
            Data_withLabel.append(temp)
            label_check.append(Case_Sw)
            temp1=[X_data_temp1,label[Case_Sw]]
            Data_withLabel1.append(temp1)
            temp=[]
            temp1=[]
        elif Case_Sw=="Double":
            X_data_double.append(X_data_temp)
            X_data_double1.append(X_data_temp1)
            temp=[X_data_temp,label[Case_Sw]]
            Data_withLabel.append(temp)
            label_check.append(Case_Sw)
            temp1=[X_data_temp1,label[Case_Sw]]
            Data_withLabel1.append(temp1)
            temp=[]
            temp1=[]
        elif Case_Sw=="One":
            X_data_one.append(X_data_temp)
            X_data_one1.append(X_data_temp1)
            temp=[X_data_temp,label[Case_Sw]]
            Data_withLabel.append(temp)
            label_check.append(Case_Sw)
            temp1=[X_data_temp1,label[Case_Sw]]
            Data_withLabel1.append(temp1)
            temp=[]
            temp1=[]
        elif Case_Sw=="Divide":
            X_data_divide.append(X_data_temp)
            X_data_divide1.append(X_data_temp1)
            temp=[X_data_temp,label[Case_Sw]]
            Data_withLabel.append(temp)
            label_check.append(Case_Sw)
            temp1=[X_data_temp1,label[Case_Sw]]
            Data_withLabel1.append(temp1)
            temp=[]
            temp1=[]
        elif Case_Sw=="Noise":
            X_data_divide.append(X_data_temp)
            X_data_divide1.append(X_data_temp1)
            temp=[X_data_temp,label[Case_Sw]]
            Data_withLabel.append(temp)
            label_check.append(Case_Sw)
            temp1=[X_data_temp1,label[Case_Sw]]
            Data_withLabel1.append(temp1)
            temp=[]
            temp1=[]

# %%
len(Data_withLabel)
# Out:
# 7464

# %%
for j in range(0,10,1):
    plt.plot(X_data_circle[j])
    plt.ylabel('Amplitude')
    plt.xlabel('time')
    plt.title("Circle_mic1"+'_'+str(j))
    plt.show()
    print(len(X_data_circle[j]))
# Out:
# 9406
# 7832
# 6810
# 4202
# 4723
# 3089
# 2314
# 3624
# 3759
# 2984

# %%
x_label_totmic1, y_label_tot = map(list, zip(*Data_withLabel))
x_label_totmic2, y_label_tot_dummy = map(list, zip(*Data_withLabel1))

y_label_tot=np.array(y_label_tot)
y_train=pd.get_dummies(y_label_tot).values

# %%
y_train.shape
# Out:
# (7464, 7)

# %%
x_label_tot1=x_label_totmic1
x_label_tot2=x_label_totmic2

n_train=len(x_label_tot1)-1500
n_total=len(x_label_tot1)

# %%
n_train
# Out:
# 5964

# %%
x_label_tot1_train=[]
x_label_tot2_train=[]
for j in range(0,n_train,1):
    temp_train1 = x_label_tot1[j][0:6000]
    temp_train2 = x_label_tot2[j][0:6000]
    x_label_tot1_train.append(temp_train1)
    x_label_tot2_train.append(temp_train2)

x_label_tot1_test=[]
x_label_tot2_test=[]
for j in range(n_train,n_total,1):
    temp_test1 = x_label_tot1[j][0:6000]
    temp_test2 = x_label_tot2[j][0:6000]
    x_label_tot1_test.append(temp_test1)
    x_label_tot2_test.append(temp_test2)

# %%
X_train1=x_label_tot1_train
X_train2=x_label_tot2_train
X_test1=x_label_tot1_test
X_test2=x_label_tot2_test

y_train1=y_train[0:n_train]
y_test1=y_train[n_train:n_total]

# %%
length = len(sorted(X_train1,key=len, reverse=True)[0])
X_train=np.array([xi+[0]*(length-len(xi)) for xi in X_train1])
print(X_train.shape)

length = len(sorted(X_test1,key=len, reverse=True)[0])
X_test=np.array([xi+[0]*(length-len(xi)) for xi in X_test1])
X_test.shape
# Out:
# (5964, 6000)
# (1500, 6000)

# %%
X_train_CNN = np.expand_dims(X_train, axis=2)
X_test_CNN = np.expand_dims(X_test, axis=2)

# %%
Y_train=np.array(y_train1)
Y_test=np.array(y_test1)

print(Y_test.shape)
print(Y_train.shape)
# Out:
# (1500, 7)
# (5964, 7)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv1D, GlobalAveragePooling1D, MaxPooling1D
from keras.layers import GRU
from keras.layers.normalization import BatchNormalization

config = tf.ConfigProto(log_device_placement=True, allow_soft_placement=True, device_count = {'GPU' : 4})
config.gpu_options.allow_growth=True
#config.gpu_options.per_process_gpu_memory_fraction=0.40
config.gpu_options.allocator_type = 'BFC'
with tf.device('/gpu:0'):
    session = tf.Session(config=config)
    tf.keras.backend.set_session
    
    model = Sequential()

    model.add(Conv1D(32,3, activation='relu', input_shape=(6000, 1)))
    model.add(BatchNormalization())
    
    model.add(MaxPooling1D(3))
    
    model.add(Conv1D(32, 3, activation='relu'))
    model.add(BatchNormalization())

    model.add(GRU(64,return_sequences=True))
    model.add(BatchNormalization())
    
    model.add(MaxPooling1D(35))
    model.add(Flatten())
    
    model.add(Dense(units = 128, activation='relu'))

    model.add(Dense(7, activation='softmax'))
    model.summary()
    model.compile(loss='categorical_crossentropy',
                  optimizer='Adam',
                  metrics=['accuracy'])

    history=model.fit(X_train_CNN, Y_train, batch_size=64,shuffle=True, epochs=15,verbose=1,validation_data=(X_test_CNN, Y_test))

    score, acc = model.evaluate(X_test_CNN, Y_test, batch_size=16)
    print(acc)
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 5998, 32)          128
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 5998, 32)          128
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 1999, 32)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 1997, 32)          3104
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1997, 32)          128
# _________________________________________________________________
# gru_1 (GRU)                  (None, 1997, 64)          18624
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1997, 64)          256
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 57, 64)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3648)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               467072
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 490,343
# Trainable params: 490,087
# Non-trainable params: 256
# _________________________________________________________________
# Train on 5964 samples, validate on 1500 samples
# Epoch 1/15
# 5964/5964 [==============================] - 390s 65ms/step - loss: 1.1288 - acc: 0.6452 - val_loss: 1.6147 - val_acc: 0.5947
# Epoch 2/15
# 5964/5964 [==============================] - 386s 65ms/step - loss: 0.5008 - acc: 0.8431 - val_loss: 1.4415 - val_acc: 0.6647
# Epoch 3/15
# 5964/5964 [==============================] - 374s 63ms/step - loss: 0.3645 - acc: 0.8815 - val_loss: 1.4798 - val_acc: 0.6693
# Epoch 4/15
# 5964/5964 [==============================] - 375s 63ms/step - loss: 0.2956 - acc: 0.9078 - val_loss: 1.2740 - val_acc: 0.7140
# Epoch 5/15
# 5964/5964 [==============================] - 377s 63ms/step - loss: 0.2383 - acc: 0.9269 - val_loss: 1.2635 - val_acc: 0.7207
# Epoch 6/15
# 5964/5964 [==============================] - 378s 63ms/step - loss: 0.1778 - acc: 0.9458 - val_loss: 1.4489 - val_acc: 0.7060
# Epoch 7/15
# 5964/5964 [==============================] - 379s 64ms/step - loss: 0.1493 - acc: 0.9536 - val_loss: 1.4070 - val_acc: 0.7347
# Epoch 8/15
# 5964/5964 [==============================] - 378s 63ms/step - loss: 0.1126 - acc: 0.9648 - val_loss: 1.4880 - val_acc: 0.7327
# Epoch 9/15
# 5964/5964 [==============================] - 379s 64ms/step - loss: 0.0920 - acc: 0.9752 - val_loss: 1.4601 - val_acc: 0.7367
# Epoch 10/15
# 5964/5964 [==============================] - 390s 65ms/step - loss: 0.0832 - acc: 0.9760 - val_loss: 1.7072 - val_acc: 0.6980
# Epoch 11/15
# 5964/5964 [==============================] - 424s 71ms/step - loss: 0.0692 - acc: 0.9795 - val_loss: 1.7485 - val_acc: 0.7127
# Epoch 12/15
# 5964/5964 [==============================] - 425s 71ms/step - loss: 0.0752 - acc: 0.9802 - val_loss: 1.7115 - val_acc: 0.6900
# Epoch 13/15
# 5964/5964 [==============================] - 425s 71ms/step - loss: 0.0653 - acc: 0.9807 - val_loss: 1.8225 - val_acc: 0.7173
# Epoch 14/15
# 5964/5964 [==============================] - 425s 71ms/step - loss: 0.0374 - acc: 0.9909 - val_loss: 1.8249 - val_acc: 0.7067
# Epoch 15/15
# 5964/5964 [==============================] - 424s 71ms/step - loss: 0.0455 - acc: 0.9889 - val_loss: 2.0438 - val_acc: 0.7067
# 1500/1500 [==============================] - 151s 101ms/step
# 0.7066666665077209

# %%
from sklearn.metrics import confusion_matrix
pred_classes=model.predict_classes(X_test_CNN)
num_ytest=[ np.where(r==1)[0][0] for r in Y_test ]
num_ytest
confusion=confusion_matrix(num_ytest,pred_classes)
confusion
# Out:
# array([[163,   2,   7,   5,  26,   5,  17],
#        [  1, 150,  28,  10,  22,  13,   5],
#        [  5,  12, 140,  11,  31,   7,   5],
#        [  1,   2,   2, 197,  21,   6,   3],
#        [  4,   9,   6,   6, 179,   5,   1],
#        [  4,   9,  10,  10,  15, 132,   8],
#        [ 30,  11,  17,   5,   8,  22, 112]])

# %%
plt.plot(history.history['acc'], label='train')
plt.plot(history.history['val_acc'], label='test')
plt.legend()
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.show()

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2665efbbdf64> in <module>()
# ----> 1 plt.plot(history.history['loss'], label='train')
#       2 plt.plot(history.history['val_loss'], label='test')
#       3 plt.legend()
#       4 plt.ylabel('Loss')
#       5 plt.xlabel('Epochs')
#
# NameError: name 'plt' is not defined

# %%
model.save('CNN_GRU.h5')
